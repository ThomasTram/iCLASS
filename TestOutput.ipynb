# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from classy import Class

# %%
font = {'size'   : 16, 'family':'STIXGeneral'}
axislabelfontsize='large'
matplotlib.rc('font', **font)
matplotlib.mathtext.rcParams['legend.fontsize']='medium'

# %%
cosmo = Class()
cosmo.set({'k_output_values':'0.01, 0.1, 0.0001','output':'tCl'})
cosmo.compute()
perturb = cosmo.get_perturbations()
background = cosmo.get_background()
thermo = cosmo.get_thermodynamics()

# %%
background.viewkeys()
# Out:
# dict_keys(['(.)rho_crit', 'lum. dist.', '(.)rho_b', 'H_prime_prime', 'H_prime', 'conf. time [Mpc]', '(.)rho_ur', '(.)rho_g', '(.)rho_lambda', 'comov. dist.', '(.)rho_cdm', 'ang.diam.dist.', 'proper time [Gyr]', 'gr.fac. D', 'gr.fac. f', 'z', 'comov.snd.hrz.', 'H [1/Mpc]'])

# %%
plt.loglog(background['conf. time [Mpc]'], background['(.)rho_cdm'],
        background['conf. time [Mpc]'], background['(.)rho_g'],
        background['conf. time [Mpc]'], background['(.)rho_lambda'])

# %%
thermo.viewkeys()
# Out:
# dict_keys(['x_e', 'g [Mpc^-1]', 'conf. time [Mpc]', "kappa' [Mpc^-1]", 'tau_d', 'Tb [K]', 'c_b^2', 'exp(-kappa)', 'z'])

# %%
plt.loglog(thermo['z'], thermo['x_e'])

# %%
sarray = perturb['scalar']
sdict = sarray[0]
sdict.viewkeys
tau = sdict['tau [Mpc]']
delta_cdm = sdict['delta_cdm']
plt.plot(tau,delta_cdm)
